# %%
str1 = "Hello"

# %%
print(str1)
# Out:
# Hello

# %%
x = "Great"

# %%
print("You are {}".format(x))
# Out:
# You are Great

# %%
print("{}, You are {}".format(str1, x))
# Out:
# Hello, You are Great

# %%
len(x)
# Out:
# 5

# %%
str2 = "You are Great"

# %%
str3 = str2.replace("Great", "Awesome")

# %%
str3
# Out:
# 'You are Awesome'

# %%
str2
# Out:
# 'You are Great'

# %% [raw]
# String indexing

# %%
str3
# Out:
# 'You are Awesome'

# %%
str3[2]
# Out:
# 'u'

# %%
str3[2:8]
# Out:
# 'u are '

# %%
str3[-1]
# Out:
# 'e'

# %%
str3[:5]
# Out:
# 'You a'

# %%
str3[5:]
# Out:
# 're Awesome'

# %%
str3[1:10:2]
# Out:
# 'o r w'

# %%
type(str3)
# Out:
# str

# %%
var1 = 5

# %%
type(var1)
# Out:
# int

# %%
var2 = 6/4

# %%
var2
# Out:
# 1.5

# %%
type(var2)
# Out:
# float
