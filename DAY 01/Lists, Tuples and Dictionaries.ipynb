# %% [markdown]
# Lists

# %%
l1 = [1,2,3,4,5]

# %%
type(l1)
# Out:
# list

# %%
print(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
l1[0]
# Out:
# 1

# %%
l1[0:3] #get from index 0 to 2
# Out:
# [1, 2, 3]

# %%
l1[::2] #get all items with the spacing of 2
# Out:
# [1, 3, 5]

# %%
l2 = [1, "a", 2.5]

# %%
type(l2[0])
# Out:
# int

# %%
type(l2[1])
# Out:
# str

# %%
type(l2)
# Out:
# list

# %%
l3 = [l2, 1, 2.0]

# %%
print(l3)
# Out:
# [[1, 'a', 2.5], 1, 2.0]

# %%
type(l3[0])
# Out:
# list

# %%
l3[0][1] #index through the lists
# Out:
# 'a'

# %%
l3[0][0]
# Out:
# 1

# %%
list(range(0,10,2)) #Create a list of 0 to 10 with the step of 2 spaces
# Out:
# [0, 2, 4, 6, 8]

# %%
l4 = list(range(0,10,2))

# %%
l4
# Out:
# [0, 2, 4, 6, 8]

# %%
l4.sort(reverse = True) #sorting in descending order

# %%
l4
# Out:
# [8, 6, 4, 2, 0]

# %%
l4.append(10) #adding new element or item at the end of the list

# %%
l4
# Out:
# [8, 6, 4, 2, 0, 10, 10]

# %%
l4[0] = 3 #changing the value using the index position

# %%
l4
# Out:
# [3, 6, 4, 2, 0, 10, 10]

# %%
l4[1:3] = [5,7]

# %%
l4
# Out:
# [3, 5, 7, 2, 0, 10, 10]

# %%
l4.insert(0, "15")

# %%
l4
# Out:
# ['15', 3, 5, 7, 2, 0, 10, 10]

# %%
l4.remove(3) #it sees for the value and deletes it

# %%
l4
# Out:
# ['15', 5, 7, 2, 0, 10, 10]

# %%
del l4[0] #it deletes using the index position

# %%
l4
# Out:
# [5, 7, 2, 0, 10, 10]

# %% [markdown]
# Tuples

# %% [markdown]
# Tuples are just like list but you cannot modified once they created.

# %%
t1 = (1,2)

# %%
t1
# Out:
# (1, 2)

# %%
t1[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18312\862528157.py in <module>
# ----> 1 t1[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
type(t1)
# Out:
# tuple

# %% [markdown]
# Dictionary

# %% [markdown]
# Dictionaries using key value pairs instead of indexing values

# %%
d1 = {"key1": 1,
     "key2": 2,
     "key3": 3}

# %%
d1
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3}

# %%
type(d1)
# Out:
# dict

# %%
d1["key1"] #using the key to get the element
# Out:
# 1

# %%
d1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18312\3367005619.py in <module>
# ----> 1 d1[0]
#
# KeyError: 0
